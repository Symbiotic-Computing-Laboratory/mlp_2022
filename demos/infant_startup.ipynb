# %% [markdown]
# #Example of loading infant data from the MLP_2021 shared drive
# ### Author: Andrew H. Fagg (andrewhfagg@gmail.com)
# *   This example assumes that there is already a shortcut to MLP_2021 from your Drive

# %%
import numpy as np
import pickle as pkl
from google.colab import drive
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Mount your Google Drive into the local virtual machine file system (will give a warning if already mounted)
# If asked, follow the directions to authenticate with your Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load a baby dataset
fname = '/content/drive/MyDrive/MLP_2021/datasets/baby1/subject_k1_w10_hw2.csv'

# %%
infant_data = pd.read_csv(fname)

# %%
infant_data.head
# Out:
# <bound method NDFrame.head of          time  left_wrist_x  ...  right_wrist_y  right_wrist_z
# 0        0.00           NaN  ...      -0.113438      -0.154972
# 1        0.02           NaN  ...      -0.113476      -0.154807
# 2        0.04           NaN  ...      -0.113521      -0.154429
# 3        0.06           NaN  ...      -0.113555      -0.154063
# 4        0.08      0.163611  ...      -0.113534      -0.153886
# ...       ...           ...  ...            ...            ...
# 14995  299.90      0.371656  ...      -0.073395      -0.310776
# 14996  299.92      0.371723  ...      -0.073288      -0.310726
# 14997  299.94      0.371801  ...      -0.073102      -0.310798
# 14998  299.96      0.371866  ...      -0.072929      -0.310848
# 14999  299.98      0.371907  ...      -0.072672      -0.310929
#
# [15000 rows x 7 columns]>

# %%
infant_data
# Out:
#          time  left_wrist_x  ...  right_wrist_y  right_wrist_z
# 0        0.00           NaN  ...      -0.113438      -0.154972
# 1        0.02           NaN  ...      -0.113476      -0.154807
# 2        0.04           NaN  ...      -0.113521      -0.154429
# 3        0.06           NaN  ...      -0.113555      -0.154063
# 4        0.08      0.163611  ...      -0.113534      -0.153886
# ...       ...           ...  ...            ...            ...
# 14995  299.90      0.371656  ...      -0.073395      -0.310776
# 14996  299.92      0.371723  ...      -0.073288      -0.310726
# 14997  299.94      0.371801  ...      -0.073102      -0.310798
# 14998  299.96      0.371866  ...      -0.072929      -0.310848
# 14999  299.98      0.371907  ...      -0.072672      -0.310929
#
# [15000 rows x 7 columns]
