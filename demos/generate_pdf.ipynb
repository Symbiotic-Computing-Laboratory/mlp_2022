# %% [markdown]
# ## Generate a PDF for Homework Submission
# ### Machine Learning Practice, Fall 2021
#
# 1. Complete and execute the notebook containing your assignment.  **Save this notebook to your Google Drive**
# 2. Fill in the parameter below that contains the name of the notebook file
# 3. Execute the cells.  The last cell will generate a pdf file in the same Google Drive folder as your notebook file.
#
# Note: if you need to convert multiple files, then you only need to change the notebook_path and execute the !jupyter cell (the last one)

# %%
# 2.  Fill in the parameter below that contains the name of the notebook file
notebook_path = '/content/drive/MyDrive/Colab Notebooks/mlp/pandas_examples.ipynb'

# %%
# 3.  Execute

# DO NOT EDIT

# install latex 
# !apt update
# !apt install texlive-xetex texlive-fonts-recommended texlive-generic-recommended inkscape

import re, pathlib, shutil
import os
from google.colab import drive

# %%
# 3. Execute

# DO NOT EDIT

# Mount your Google Drive into the local virtual machine file system (will give a warning if already mounted)
# If asked, follow the directions to authenticate with your Google Drive
drive.mount('/content/drive')

# %%
# 3. Execute

# DO NOT EDIT

# Generate the pdf
# !jupyter nbconvert "{notebook_path}" --to pdf
